# %% [markdown]
# ## 1주차 매일과제 (5/24~5/27)

# %% [markdown]
# ### 210525

# %% [markdown]
# ### 강의 학습 목표
#
# 1. 전 수업 복습 - 변수, 배열, 범위(range), 반복문, 조건문
# 2. 코랩 환경설정 - 텍스트셀, 코드셀 조작/제목변경/파일 불러오기 및 저장/폰트 크기 변경 및 설정
# 3. 코드 주석달기
# 4. 파이썬 자료형, 형 변환 함수, 입력값(input) 받기, 출력(print, f스트링) 하기 및 실습
# 5. 산술 연산자 개념 및 실습 (화씨에서 섭씨 변환기, 삼각형/원의 넓이 구하기)
# 6. 할당 연산자, 복합할당 연산자 개념 및 실습
# 7. 문자열 반복/연결 개념 및 실습 - 기사만들기, 광고만들기, 성적계산프로그램,커피가게 매출 계산하기
# 8. 크롬 기본 폰트 설정 - D2Coding
# 9. 문자 분할(split) / 결합(join)

# %%
print("hello, Python ")
# Out:
# hello, Python

# %%
 print("hello, Python
# Out:
#   File "<ipython-input-2-d3be65043ed8>", line 1
#     print("hello, Python
#                          ^
# SyntaxError: EOL while scanning string literal

# %%
if < 0:
print('hello')
# Out:
#   File "<ipython-input-3-b5b42259418d>", line 1
#     if < 0:
#        ^
# SyntaxError: invalid syntax

# %%
n = 1
print(n)
print(type(n))
print(id(n))
# Out:
# 1
# <class 'int'>
# 94816746506752

# %%
n = True
print(n)
print(type(n))
print(id(n))
# Out:
# True
# <class 'bool'>
# 94816745832704

# %%
test1 = 1
print(test1)
print(type(test1))   # 데이터 형
print(id(test1))     # 데이터 주소
# Out:
# 1
# <class 'int'>
# 94816746506752

# %%
n = [1,2,3,5,]
print(n)
print(type(n))
print(id(n))
# Out:
# [1, 2, 3, 5]
# <class 'list'>
# 139792583347648

# %%
n = (1,2,3,4,)
print(n)
print(type(n))
print(id(n))
# Out:
# (1, 2, 3, 4)
# <class 'tuple'>
# 139792650289520

# %%
n = {'name','john', 'age'}
print(n)
print(type(n))
print(id(n))
# Out:
# {'john', 'name', 'age'}
# <class 'set'>
# 139792721797920

# %%
n = {'name':'john', 'age':15}
print(n)
print(type(n))
print(id(n))
# Out:
# {'name': 'john', 'age': 15}
# <class 'dict'>
# 139792649843248

# %%
a = ''' 안녕하세요.
파이썬을 배워보자요.
이렇게 하면 줄바꿈이 되지롱 '''

print(a)
# Out:
#  안녕하세요.
# 파이썬을 배워보자요.
# 이렇게 하면 줄바꿈이 되지롱

# %%
b = "'낮말'은 새가 듣고 '밤말'은 쥐가 듣는다"
print(b)
# Out:
# '낮말'은 새가 듣고 '밤말'은 쥐가 듣는다

# %%
c = '"시간은 금"이다'
print(c)
# Out:
# "시간은 금"이다

# %%
a = 1>2
print(a)

d = 1<2
print(d)
# Out:
# False
# True

# %%
a,b = 10,20
print(a+b)
# Out:
# 30

# %%
a,b = "10", "20"
print(a+b)
# Out:
# 1020

# %%
a,b = "10", 20
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-a2c828842e4d> in <module>()
#       1 a,b = "10", 20
# ----> 2 print(a+b)
#
# TypeError: can only concatenate str (not "int") to str

# %%
a,b = 10.0, 20
print(a+b)
# Out:
# 30.0

# %%
#형변환
a,b = "10", 20
print(int(a)+b)
# Out:
# 30

# %%
a,b = 10,20
print(str(a)+str(b))
# Out:
# 1020

# %%
name = input("이름을 입력하세요 : ")
print(name, '님 안녕하세요.')
# Out:
# 이름을 입력하세요 : 오채린
# 오채린 님 안녕하세요.

# %%
print("1더하기 2는", 2+3)
# Out:
# 1더하기 2는 5

# %%
age = 10
print("나는", age, "살 입니다.")
# Out:
# 나는 10 살 입니다.

# %%
print("hello", "world") # 공백 추가시 쉼표
# Out:
# hello world

# %%
name = input("이름을 입력하세요 : ")
print(f'{name}님 안녕하세요.') #f'' : 따옴표안에 변수명을 그대로 포함하여 출력하고 싶은 문장을 넣는다.
# Out:
# 이름을 입력하세요 : 서윤선
# 서윤선님 안녕하세요.

# %%
print("두 수를 입력받아 더하는 프로그램 입니다.")
first = input("첫번째 숫자를 입력하세요:")
second = input("두번째 숫자를 입력하세요:")

print(f'{first}+{second} = {int(first)+int(second)}')
# Out:
# 두 수를 입력받아 더하는 프로그램 입니다.
# 첫번째 숫자를 입력하세요:10
# 두번째 숫자를 입력하세요:20
# 10+20 = 30

# %%
print("두 수를 입력받아 더하는 프로그램 입니다.")
first = int(input("첫번째 숫자를 입력하세요:"))
second = int(input("두번째 숫자를 입력하세요:"))

print(f'{first}+{second} = {first}+{second}')
# Out:
# 두 수를 입력받아 더하는 프로그램 입니다.
# 첫번째 숫자를 입력하세요:20
# 두번째 숫자를 입력하세요:10
# 20+10 = 30

# %%
#산술연산

a,b = 5,8
print(a+b, a-b, a**b, a%b, a//b, a/b)
# Out:
# 13 -3 390625 5 0 0.625

# %%
a,b = 3, 0 #오류
print(a/b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-39-3d5ac0677dfb> in <module>()
#       1 a,b = 3, 0
# ----> 2 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
user = int(input("화씨온도: "))
print("섭씨온도:", (user - 32)*5/9)
# Out:
# 화씨온도: 100
# 섭씨온도: 37.77777777777778

# %%
#삼각형 넓이
bottom = float(input("밑변:"))
hight = float(input("높이:"))

print(f'삼각형의 넓이 : {(bottom*hight)/2}')
# Out:
# 밑변:3
# 높이:4
# 삼각형의 넓이 : 6.0

# %%
#원의 넓이
circle = float(input('원의 반지름: '))
p = 3.14
print(f'원의 둘레:{2*p*circle} 원의 넓이:{p*(circle**2)}')
# Out:
# 원의 반지름: 3
# 원의 둘레:18.84 원의 넓이:28.26

# %%
#할당연산자
a = 1
print(a)
# Out:
# 1

# %%
a = b = c = 1
print(a,b,c)
# Out:
# 1 1 1

# %%
a,b,c = 1, 2, 3
print(a,b,c)
# Out:
# 1 2 3

# %%
#복합할당연산자
x = 3
y = 5
x *= x+y
print(x)
# Out:
# 24

# %%
x = 10
x += 20
print(x)
# Out:
# 30

# %%
#문자열 반복
s = "hi"
print(s*5)
# Out:
# hihihihihi

# %%
name = input("이름을 입력하세요:")
greet = name + '님 안녕'
print(greet)
# Out:
# 이름을 입력하세요:sunny
# sunny님 안녕

# %%
eng = 80
result = '영어점수:' +eng +'점'
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-6a669d128288> in <module>()
#       1 eng = 80
# ----> 2 result = '영어점수:' +eng +'점'
#       3 print(result)
#
# TypeError: can only concatenate str (not "int") to str

# %%
eng = 80
result = '영어점수:' +str(eng) +'점'
print(result)
# Out:
# 영어점수:80점

# %%
#로봇 기자 만들기
'''
오늘{경기장}에서 경기가 열렸습니다.
{이긴팀}과 {진팀}은 치열한 공방전을 펼쳤습니다.
{vip}가 맹활약을 펼쳤습니다.
결국{이긴팀}이 {진팀}을 {스코어}로 이겼습니다
'''

cort = input("경기장: ")
win_score = int(input ("이긴팀 점수: "))
loose_score = int(input("진팀 점수: "))
vip = str(input("mvp선수: "))
win = '청팀'
loose = '백팀'
print('---'*50)
print(f'''오늘 {cort} 에서 경기가 열렸습니다.
{win}과 {loose}은 치열한 공방전을 펼쳤습니다.
{vip}가 맹활약을 펼쳤습니다.
결국{win}이 {loose}을 {(win_score - loose_score)} 차이로 이겼습니다''')
# Out:
# 경기장: 운동장
# 이긴팀 점수: 1000
# 진팀 점수: 800
# mvp선수: 오채린
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 오늘 운동장 에서 경기가 열렸습니다.
# 청팀과 백팀은 치열한 공방전을 펼쳤습니다.
# 오채린가 맹활약을 펼쳤습니다.
# 결국청팀이 백팀을 200 차이로 이겼습니다

# %%
ground = input('경기장은 어디입니까? ')
winner = input('이긴 팀은 어디입니까? ')

# %%
#광고 템플릿

'''
{지역}에 위치한 아주 좋은 {매물종류}가 매물로 나왔습니다. 이 {매물종류}는 {평}평으로 {방갯수}개의 방을 가지고 있습니다.
가격은 {가격}만원 입니다. '''

region = input("지역은 어디입니까? ") 
sale = input("매물은 무엇입니까? ") 
area = input("면적은 얼마입니까? ") 
room = input("방은 몇 개 입니까? ") 
price = input("가격은 얼마 입니까? ") 

print('---'*50)
print(f'''{region}에 위치한 아주 좋은 {sale}가 매물로 나왔습니다. 이 {sale}는 {area}평으로 {room}개의 방을 가지고 있습니다.
가격은 {price}만원 입니다.''')
# Out:
# 지역은 어디입니까? 서울
# 매물은 무엇입니까? 사무실
# 면적은 얼마입니까? 100평
# 방은 몇 개 입니까? 10개
# 가격은 얼마 입니까? 1000만원
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 서울에 위치한 아주 좋은 사무실가 매물로 나왔습니다. 이 사무실는 100평평으로 10개개의 방을 가지고 있습니다.
# 가격은 1000만원만원 입니다.

# %%
team = input("팀명은? ") 
num = input("몇명입니까? ") 
good = input("장점은? ") 
good2 = input("두번째 장점은? ") 
come = input("코드메이트는 누구입니까? ") 

print('---'*50)
print(f'''매직에꼴에 {team}이라는 아주 좋은 {sale}명의  팀이 있습니다. 이 {sale}은 {good}이 뛰어나고 {good2}도 좋습니다.
이 팀을 맡아준  {come}님도 만만치 않게 멋진 분입니다.''')
# Out:
# 팀명은? 넘버원
# 몇명입니까? 6명
# 장점은? 학구열
# 두번째 장점은? 마음씨
# 코드메이트는 누구입니까? 장예훈
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 매직에꼴에 넘버원이라는 아주 좋은 6명명의  팀이 있습니다. 이 6명은 학구열이 뛰어나고 마음씨도 좋습니다.
# 이 팀을 맡아준  장예훈님도 만만치 않게 멋진 분입니다.

# %%
name = input("이름을 입력하세요: ")
write = int(input('국어 성적을 입력하세요:'))
eng= int(input('영어 성적을 입력하세요:'))
math = int(input('수학 성적을 입력하세요:'))

print('---'*30)
print(f'{name} 평균성적은 {(write + eng + math)/3} 점입니다')
# Out:
# 이름을 입력하세요: 파이썬
# 국어 성적을 입력하세요:90
# 영어 성적을 입력하세요:90
# 수학 성적을 입력하세요:97
# ------------------------------------------------------------------------------------------
# 파이썬 평균성적은 92.33333333333333 점입니다

# %%
name = str(input("이름을 입력하세요: "))
kor = float(input("국어성적을 입력하세요: "))
eng = float(input("영어성적을 입력하세요: "))
math = float(input("수학성적을 입력하세요: "))
avg = (kor+eng+math)/3
print("-"*50)
print(f"{name}평균성적은 {round((avg),2)} 점입니다.")
# Out:
# 이름을 입력하세요: 파이싼
# 국어성적을 입력하세요: 90
# 영어성적을 입력하세요: 90
# 수학성적을 입력하세요: 97
# --------------------------------------------------
# 파이싼평균성적은 92.33 점입니다.

# %%
#커피가게 매출계산하기

'''커피종류별 판매 개수에 따른 매출을 계산하는 프로그램을 코딩'''

menu = {'아메리카노':2000, '카페라떼':3000, '카푸치노':3500}
order_m = input('주문하세요.')
order_n = input('주문하세요.')
sum_m = 

print(f'주문하신 음료는 {order_m}이고, {(sum_m)*(order_n)}입니다.')
# Out:
# 주문하세요.아메리카노
# 주문하세요.1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-4fae047ba6e9> in <module>()
#       6 order_m = input('주문하세요.')
#       7 order_n = input('주문하세요.')
# ----> 8 sum_m = menu['order_m']
#       9
#      10 print(f'주문하신 음료는 {order_m}이고, {(sum_m)*(order_n)}입니다.')
#
# KeyError: 'order_m'

# %%
menu = {'아메리카노':2000, '카페라떼':3000, '카푸치노':3500}
print(menu['아메리카노'])
# Out:
# 2000

# %%
a = int(input('아메리카노 갯수:'))
b = int(input('카페라떼 갯수:'))
c = int(input('카푸치노 갯수:'))

a *= 2000
b *= 3000
c *= 3500

print(f'총 매출은 {(a+b+c)}입니다')
# Out:
# 아메리카노 갯수:10
# 카페라떼 갯수:20
# 카푸치노 갯수:30
# 총 매출은 185000입니다

# %%
# 1팀_Zoey님 코드

ame_price=2000
cafe_price=3000
cafu_price=3500
ame=int(input('아메리카노 판매 갯수:'))
cafe=int(input('카페라떼 판매 갯수:'))
cafu=int(input('카푸치노 판매 갯수:'))
total_income=((ame*ame_price)+(cafe*cafe_price)+(cafu*cafu_price))
print(f'총 매출은 {total_income}원 입니다')
# Out:
# 아메리카노 판매 갯수:10
# 카페라떼 판매 갯수:20
# 카푸치노 판매 갯수:30
# 총 매출은 185000원 입니다

# %%
print('셀 병합\n \t \'shift key\' 를누른 후 \n \t \t 병합을 원하는 셀들을 다중 선택 후 shift+M')
# Out:
# 셀 병합
#  	 'shift key' 를누른 후
#  	 	 병합을 원하는 셀들을 다중 선택 후 shift+M

# %%
print('-'.join('hello world'))#인자 사이에 '-'을 추가
# Out:
# h-e-l-l-o- -w-o-r-l-d

# %%
print('welcome to python'.split(' ')) # 공백을 기준으로 분리
# Out:
# ['welcome', 'to', 'python']

# %%
a = 8 == 12
print(a, type(a))
# Out:
# False <class 'bool'>

# %%
b = 'apple' == 'APPLE'
print(b, type(b))
# Out:
# False <class 'bool'>

# %%
c = 8 != 12
print(c, type(c))
# Out:
# True <class 'bool'>
